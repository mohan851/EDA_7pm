# %%
import numpy as np
import pandas as pd
data = {"names" : ["ramesh" , "suresh" , "sathish" , np.nan] , 
       "age" : [np.nan , 22,25,27] ,
       "city" : ["pune" , "pune" , np.nan , "hyd"]}
df = pd.DataFrame(data= data)
df.to_csv("missing_values_numpy.csv" , index= False )
df
# Out:
#      names   age  city
# 0   ramesh   NaN  pune
# 1   suresh  22.0  pune
# 2  sathish  25.0   NaN
# 3      NaN  27.0   hyd

# %%
import numpy as np
import pandas as pd
data = {"names" : ["ramesh" , "suresh" , "sathish" , None] , 
       "age" : [None , 22,25,27] ,
       "city" : ["pune" , "pune" , None , "hyd"]}
df1 = pd.DataFrame(data= data)
df1.to_csv("missing_values_None.csv" , index= False )
df1
# Out:
#      names   age  city
# 0   ramesh   NaN  pune
# 1   suresh  22.0  pune
# 2  sathish  25.0  None
# 3     None  27.0   hyd

# %%
df.dtypes
# Out:
# names     object
# age      float64
# city      object
# dtype: object

# %%
df1.dtypes
# Out:
# names     object
# age      float64
# city      object
# dtype: object

# %%
df.isnull()
# Out:
#    names    age   city
# 0  False   True  False
# 1  False  False  False
# 2  False  False   True
# 3   True  False  False

# %%
df.isnull().sum()
# Out:
# names    1
# age      1
# city     1
# dtype: int64

# %% [markdown]
# # fillna

# %%
df.fillna(30)
# Out:
#      names   age  city
# 0   ramesh  30.0  pune
# 1   suresh  22.0  pune
# 2  sathish  25.0    30
# 3       30  27.0   hyd

# %%
df['age'].fillna(30)
# Out:
# 0    30.0
# 1    22.0
# 2    25.0
# 3    27.0
# Name: age, dtype: float64

# %% [markdown]
# - --------------------------------------------------------------------------
# - the above ine us we aew filling randomly
# - all the columns are filled with random number
# - it is not a good approach because in a data we have different data types

# %% [markdown]
# # what is the difference between np.nan and None

# %% [markdown]
# ### in catagorical we will use **NONE**

# %% [markdown]
# ### in numerical we will use **np.nan**

# %%
np.nan+5
# Out:
# nan

# %%
None + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 None + 5
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
arr1 = np.array([1,2,np.nan,3])
arr2 = np.array([1,2,None , 3])

# %%
arr1
# Out:
# array([ 1.,  2., nan,  3.])

# %%
arr2
# Out:
# array([1, 2, None, 3], dtype=object)

# %%
np.nansum(arr1),np.sum(arr1)
# Out:
# (np.float64(6.0), np.float64(nan))

# %%
np.sum(arr2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 np.sum(arr2)
#
# File ~\anaconda3\Lib\site-packages\numpy\_core\fromnumeric.py:2485, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2482         return out
#    2483     return res
# -> 2485 return _wrapreduction(
#    2486     a, np.add, 'sum', axis, dtype, out,
#    2487     keepdims=keepdims, initial=initial, where=where
#    2488 )
#
# File ~\anaconda3\Lib\site-packages\numpy\_core\fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %% [markdown]
#  - np.nan represents **float type**
#
#  - None represents **object type**
#
#  - is data operations related to Maths then nan format is better

# %% [markdown]
# # fill the value based on a specific column

# %%
df["names"].fillna("manish")
# Out:
# 0     ramesh
# 1     suresh
# 2    sathish
# 3     manish
# Name: names, dtype: object

# %% [markdown]
# # Fill with methods

# %% [markdown]
# - when ever we are using methods no need to provide values

# %% [markdown]
# ### methods are
#
# - pad
#
# - bfill
#
# - ffill
#
# - backfill

# %%
df
# Out:
#      names   age  city
# 0   ramesh   NaN  pune
# 1   suresh  22.0  pune
# 2  sathish  25.0   NaN
# 3      NaN  27.0   hyd

# %%
import warnings
warnings.filterwarnings("ignore")
df.fillna(method = "pad" )
# Out:
#      names   age  city
# 0   ramesh   NaN  pune
# 1   suresh  22.0  pune
# 2  sathish  25.0  pune
# 3  sathish  27.0   hyd

# %%
df
# Out:
#      names   age  city
# 0   ramesh   NaN  pune
# 1   suresh  22.0  pune
# 2  sathish  25.0   NaN
# 3      NaN  27.0   hyd

# %%
df.fillna(method="bfill")
# Out:
#      names   age  city
# 0   ramesh  22.0  pune
# 1   suresh  22.0  pune
# 2  sathish  25.0   hyd
# 3      NaN  27.0   hyd

# %%
df
# Out:
#      names   age  city
# 0   ramesh   NaN  pune
# 1   suresh  22.0  pune
# 2  sathish  25.0   NaN
# 3      NaN  27.0   hyd

# %%
df.fillna(method="ffill")
# Out:
#      names   age  city
# 0   ramesh   NaN  pune
# 1   suresh  22.0  pune
# 2  sathish  25.0  pune
# 3  sathish  27.0   hyd

# %%
df.fillna(method="backfill")
# Out:
#      names   age  city
# 0   ramesh  22.0  pune
# 1   suresh  22.0  pune
# 2  sathish  25.0   hyd
# 3      NaN  27.0   hyd

# %% [markdown]
# ## MEAN_MEDIAN _MODE
#
# - instead of filling with random values
#
# - we can use mean median mode also
#
# - for numerical columns use mean and meadian
#
# - if Data outliers are there use **Median**
#
# - for catagorical columns **mode**

# %%
age_mean = np.mean(df['age'])
df['age'].fillna(age_mean)
# Out:
# 0    24.666667
# 1    22.000000
# 2    25.000000
# 3    27.000000
# Name: age, dtype: float64

# %%
age_mean
# Out:
# np.float64(24.666666666666668)

# %%
df['city'].mode().values.tolist()[0]
# Out:
# 'pune'
