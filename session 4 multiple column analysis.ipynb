# %%
import pandas as pd

# %%
path = "Visadataset.csv"

# %%
visadf = pd.read_csv(path)

# %%
visadf
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
keys = visadf['education_of_employee'].value_counts().keys().to_list()

# %%
keys
# Out:
# ["Bachelor's", "Master's", 'High School', 'Doctorate']

# %%
values = visadf['education_of_employee'].value_counts().values.tolist()

# %%
values
# Out:
# [10234, 9634, 3420, 2192]

# %%
education = pd.DataFrame(data = zip(keys,values),columns=["degree" ," population"])

# %%
education
# Out:
#         degree   population
# 0   Bachelor's        10234
# 1     Master's         9634
# 2  High School         3420
# 3    Doctorate         2192

# %%
import matplotlib.pyplot as plt

# %%
plt.xlabel("degree")
plt.bar(x = keys ,height= values)
# Out:
# <BarContainer object of 4 artists>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "Visadata.csv"

# %% [markdown]
# # FRequenct Table

# %%
visadf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# # idea

# %% [markdown]
# - i want to create all frequency tables
#
# -  and save in a new folder
#
# -  the folder is avilable in pyhton current file location
#
# -  all stps should be automate

# %% [markdown]
# # step -1 : create a folder using pythin code

# %%
import os
try:
    os.makedirs("frequency_table")
except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'frequency_table'

# %% [markdown]
# # method - 2

# %%
 os.makedirs("frequency_table1", exist_ok=True)

# %%
keys = visadf['continent'].value_counts().keys().to_list()
values = visadf['continent'].value_counts().values.tolist()
df = pd.DataFrame(data = zip(keys,values) , columns=["continents" , "population"])
df.to_csv("continent.csv", index=False)

# Absolute path

path = r"C:\Users\Admin\Documents\naresh IT\data packages EDA\frequency_table\continent.csv"
df.to_csv(path,index=False)

# %%
C:\Users\Admin\Documents\naresh IT\data packages EDA\frequency_table

# %%
# realtive path


path = r".\frequency_table\continent1.csv"
df.to_csv(path ,index=False)

# %%
# 

cwd = os.getcwd()
folder_name = "frequency_table"
new_dir = os.path.join(cwd , folder_name)
filename = "continent1.csv"
path= os.path.join(new_dir,filename)

# %%
df.to_csv(path , index= False)

# %%
# step -1
keys = visadf['continent'].value_counts().keys().to_list()
values = visadf['continent'].value_counts().values.tolist()
df = pd.DataFrame(data = zip(keys,values) , columns=["continents" , "population"])
df.to_csv("continent.csv", index=False)

# step -2
# folder crceation

folder_name = "frequency_table"
os.makedirs(folder_name,exist_ok= True)

# step -3
# path

current_dir = os.getcwd()
new_dir = os.path.join(current_dir , folder_name)
file_name = "continent3.csv"
path = os.path.join(new_dir , file_name)

# step 4
# making to create a new file in folder

df.to_csv(path , index = False)

# %%
cat = visadf.select_dtypes(include="object").columns

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num = visadf.select_dtypes(exclude= "object").columns

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
for i in cat[1:]:
    # step -1
    keys = visadf[i].value_counts().keys().to_list()
    values = visadf[i].value_counts().values.tolist()
    df = pd.DataFrame(data = zip(keys,values) , columns=["continents" , "population"])
    df.to_csv("continent.csv", index=False)
    
    # step -2
    # folder crceation
    
    folder_name = "frequency_table"
    os.makedirs(folder_name,exist_ok= True)
    
    # step -3
    # path
    
    current_dir = os.getcwd()
    new_dir = os.path.join(current_dir , folder_name)
    file_name = f"{i}.csv"
    path = os.path.join(new_dir , file_name)
    
    # step 4
    # making to create a new file in folder
    
    df.to_csv(path , index = False)

# %% [markdown]
# # bar chart automate

# %%
# step -1
keys = visadf["continent"].value_counts().keys().to_list()
values = visadf['continent'].value_counts().values.tolist()

plt.figure(figsize= (10,6))
plt.bar(x = keys, height= values)
plt.xlabel("labels")
plt.ylabel("count")
plt.title("continent_barchat")
plt.show()

# %% [markdown]
# # automation

# %%
for i in cat[1:]:
    # step -1
    keys = visadf[i].value_counts().keys().to_list()
    values = visadf[i].value_counts().values.tolist()
    
    plt.figure(figsize= (10,6))
    plt.bar(x = keys, height= values)
    plt.xlabel("labels")
    plt.ylabel("count")
    plt.title(f"{i}_barchat")

    folder_name = "barcharts"
    os.makedirs(folder_name,exist_ok=True)

    current  = os.getcwd()
    new_path = os.path.join(folder_name , f"{i}_barcharts.png")
    plt.savefig(new_path)

# %%
for i in cat[1:]:
    # step -1
    keys = visadf[i].value_counts().keys().to_list()
    values = visadf[i].value_counts().values.tolist()
    
    plt.figure(figsize= (10,6))
    plt.bar(x = keys, height= values)
    plt.xlabel("labels")
    plt.ylabel("count")
    plt.title(f"{i}_barchat")
    
    
    folder_name ="bar_charts"
    
    # step -3
    # path
    
    current_dir = os.getcwd()
    new_dir = os.path.join(current_dir , folder_name)
    file_name = f"{i}.jpg"
    path = os.path.join(new_dir , file_name)
    
    # step 4
    # making to create a new file in folder
    
    plt.savefig( path)
